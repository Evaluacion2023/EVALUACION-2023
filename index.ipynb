# %%
#Fuentes de referencia
co2Link='https://www.cia.gov/the-world-factbook/field/carbon-dioxide-emissions/country-comparison/'
areaLink='https://www.worldometers.info/world-population/population-by-country/'
precipitationLink='https://www.indexmundi.com/facts/indicators/AG.LND.PRCP.MM/rankings'

import pandas as pd
co2List=pd.read_html(co2Link,header=0,flavor='bs4')
areaList=pd.read_html(areaLink,header=0,flavor='bs4')
precipitationList=pd.read_html(precipitationLink,header=0,flavor='bs4')

# %%
co2=co2List[0]
area=areaList[0]
precipitation=precipitationList[0]

# %%
co2.shape,area.shape,precipitation.shape
# Out:
# ((218, 4), (234, 12), (179, 4))

# %%
co2.columns,area.columns,precipitation.columns
# Out:
# (Index(['Rank', 'Country', 'metric tonnes of CO2', 'Date of Information'], dtype='object'),
#  Index(['#', 'Country (or dependency)', 'Population  (2023)', 'Yearly  Change',
#         'Net  Change', 'Density  (P/Km²)', 'Land Area  (Km²)',
#         'Migrants  (net)', 'Fert.  Rate', 'Med.  Age', 'Urban  Pop %',
#         'World  Share'],
#        dtype='object'),
#  Index(['Rank', 'Country', 'Value', 'Year'], dtype='object'))

# %%
area.rename(columns={'Country (or dependency)': 'Country'}, inplace=True)

# %%
area
# Out:
#        #           Country  Population  (2023) Yearly  Change  Net  Change  \
# 0      1             India          1428627663         0.81 %     11454490
# 1      2             China          1425671352        -0.02 %      -215985
# 2      3     United States           339996563         0.50 %      1706706
# 3      4         Indonesia           277534122         0.74 %      2032783
# 4      5          Pakistan           240485658         1.98 %      4660796
# ..   ...               ...                 ...            ...          ...
# 229  230        Montserrat                4386        -0.09 %           -4
# 230  231  Falkland Islands                3791         0.29 %           11
# 231  232              Niue                1935         0.05 %            1
# 232  233           Tokelau                1893         1.18 %           22
# 233  234          Holy See                 518         1.57 %            8
#
#      Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  Fert.  Rate  \
# 0                 481           2973190          -486136          2.0
# 1                 152           9388211          -310220          1.2
# 2                  37           9147420           999700          1.7
# 3                 153           1811570           -49997          2.1
# 4                 312            770880          -165988          3.3
# ..                ...               ...              ...          ...
# 229                44               100                0          1.6
# 230                 0             12170                0          1.6
# 231                 7               260                0          2.4
# 232               189                10                0          2.6
# 233              1295                 0                0          NaN
#
#      Med.  Age Urban  Pop % World  Share
# 0         28.0         36 %      17.76 %
# 1         39.0         65 %      17.72 %
# 2         38.0         83 %       4.23 %
# 3         30.0         59 %       3.45 %
# 4         21.0         35 %       2.99 %
# ..         ...          ...          ...
# 229       44.0         11 %       0.00 %
# 230       40.0         62 %       0.00 %
# 231       36.0         41 %       0.00 %
# 232       27.0          0 %       0.00 %
# 233        NaN         N.A.       0.00 %
#
# [234 rows x 12 columns]

# %%
co2.merge(area,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (191, 15)

# %%
co2.merge(area,how='left',left_on='Country',right_on='Country').shape
# Out:
# (218, 15)

# %%
co2.merge(area,how='outer',left_on='Country',right_on='Country').shape
# Out:
# (261, 15)

# %%
co2.merge(precipitation,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (161, 7)

# %%
co2.merge(precipitation,how='left',left_on='Country',right_on='Country').shape
# Out:
# (218, 7)

# %%
co2.merge(precipitation,how='outer',left_on='Country',right_on='Country').shape
# Out:
# (236, 7)

# %%
area.merge(precipitation,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (165, 15)

# %%
area.merge(precipitation,how='left',left_on='Country',right_on='Country').shape
# Out:
# (234, 15)

# %%
area.merge(precipitation,how='outer',left_on='Country',right_on='Country').shape
# Out:
# (248, 15)

# %%
set(co2.Country)-set(area.Country)
# Out:
# {'Antarctica',
#  'Bahamas, The',
#  'Burma',
#  'Congo, Democratic Republic of the',
#  'Congo, Republic of the',
#  "Cote d'Ivoire",
#  'Czechia',
#  'Falkland Islands (Islas Malvinas)',
#  'Faroe Islands',
#  'Gambia, The',
#  'Gaza Strip',
#  'Jersey',
#  'Korea, North',
#  'Korea, South',
#  'Kosovo',
#  'Macau',
#  'Micronesia, Federated States of',
#  'Saint Helena, Ascension, and Tristan da Cunha',
#  'Saint Kitts and Nevis',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Sao Tome and Principe',
#  'Turkey (Turkiye)',
#  'Turks and Caicos Islands',
#  'Virgin Islands',
#  'Wake Island',
#  'West Bank'}

# %%
set(area.Country)-set(co2.Country)
# Out:
# {'Andorra',
#  'Anguilla',
#  'Bahamas',
#  'Caribbean Netherlands',
#  'Congo',
#  'Curaçao',
#  'Czech Republic (Czechia)',
#  "Côte d'Ivoire",
#  'DR Congo',
#  'Faeroe Islands',
#  'Falkland Islands',
#  'French Guiana',
#  'Gambia',
#  'Guadeloupe',
#  'Holy See',
#  'Isle of Man',
#  'Liechtenstein',
#  'Macao',
#  'Martinique',
#  'Mayotte',
#  'Micronesia',
#  'Monaco',
#  'Myanmar',
#  'North Korea',
#  'Palau',
#  'Réunion',
#  'Saint Barthelemy',
#  'Saint Helena',
#  'Saint Kitts & Nevis',
#  'Saint Martin',
#  'Saint Pierre & Miquelon',
#  'San Marino',
#  'Sao Tome & Principe',
#  'Sint Maarten',
#  'South Korea',
#  'St. Vincent & Grenadines',
#  'State of Palestine',
#  'Tokelau',
#  'Turkey',
#  'Turks and Caicos',
#  'U.S. Virgin Islands',
#  'Wallis & Futuna',
#  'Western Sahara'}

# %%
set(co2.Country)-set(precipitation.Country)
# Out:
# {'American Samoa',
#  'Antarctica',
#  'Aruba',
#  'Bahamas, The',
#  'Bermuda',
#  'British Virgin Islands',
#  'Burma',
#  'Cayman Islands',
#  'Congo, Democratic Republic of the',
#  'Congo, Republic of the',
#  'Cook Islands',
#  "Cote d'Ivoire",
#  'Czechia',
#  'Falkland Islands (Islas Malvinas)',
#  'Faroe Islands',
#  'French Polynesia',
#  'Gambia, The',
#  'Gaza Strip',
#  'Gibraltar',
#  'Greenland',
#  'Guam',
#  'Hong Kong',
#  'Jersey',
#  'Kiribati',
#  'Korea, North',
#  'Korea, South',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Laos',
#  'Macau',
#  'Maldives',
#  'Marshall Islands',
#  'Micronesia, Federated States of',
#  'Montenegro',
#  'Montserrat',
#  'Nauru',
#  'New Caledonia',
#  'Niue',
#  'Northern Mariana Islands',
#  'Saint Helena, Ascension, and Tristan da Cunha',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Sao Tome and Principe',
#  'Serbia',
#  'Slovakia',
#  'South Sudan',
#  'Syria',
#  'Taiwan',
#  'Tonga',
#  'Turkey (Turkiye)',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Virgin Islands',
#  'Wake Island',
#  'West Bank'}

# %%
set(precipitation.Country)-set(co2.Country)
# Out:
# {'Congo',
#  'Czech Republic',
#  "Côte d'Ivoire",
#  "Dem. People's Rep. Korea",
#  'Dem. Rep. Congo',
#  'Korea',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Myanmar',
#  'Slovak Republic',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Syrian Arab Republic',
#  'São Tomé and Principe',
#  'The Bahamas',
#  'The Gambia',
#  'Turkey'}

# %%
set(precipitation.Country)-set(area.Country)
# Out:
# {'Czech Republic',
#  "Dem. People's Rep. Korea",
#  'Dem. Rep. Congo',
#  'Korea',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Slovak Republic',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Syrian Arab Republic',
#  'São Tomé and Principe',
#  'The Bahamas',
#  'The Gambia'}

# %%
set(area.Country)-set(precipitation.Country)
# Out:
# {'American Samoa',
#  'Andorra',
#  'Anguilla',
#  'Aruba',
#  'Bahamas',
#  'Bermuda',
#  'British Virgin Islands',
#  'Caribbean Netherlands',
#  'Cayman Islands',
#  'Cook Islands',
#  'Curaçao',
#  'Czech Republic (Czechia)',
#  'DR Congo',
#  'Faeroe Islands',
#  'Falkland Islands',
#  'French Guiana',
#  'French Polynesia',
#  'Gambia',
#  'Gibraltar',
#  'Greenland',
#  'Guadeloupe',
#  'Guam',
#  'Holy See',
#  'Hong Kong',
#  'Isle of Man',
#  'Kiribati',
#  'Kyrgyzstan',
#  'Laos',
#  'Liechtenstein',
#  'Macao',
#  'Maldives',
#  'Marshall Islands',
#  'Martinique',
#  'Mayotte',
#  'Micronesia',
#  'Monaco',
#  'Montenegro',
#  'Montserrat',
#  'Nauru',
#  'New Caledonia',
#  'Niue',
#  'North Korea',
#  'Northern Mariana Islands',
#  'Palau',
#  'Réunion',
#  'Saint Barthelemy',
#  'Saint Helena',
#  'Saint Kitts & Nevis',
#  'Saint Lucia',
#  'Saint Martin',
#  'Saint Pierre & Miquelon',
#  'San Marino',
#  'Sao Tome & Principe',
#  'Serbia',
#  'Sint Maarten',
#  'Slovakia',
#  'South Korea',
#  'South Sudan',
#  'St. Vincent & Grenadines',
#  'State of Palestine',
#  'Syria',
#  'Taiwan',
#  'Tokelau',
#  'Tonga',
#  'Turks and Caicos',
#  'Tuvalu',
#  'U.S. Virgin Islands',
#  'Wallis & Futuna',
#  'Western Sahara'}

# %%
cia=co2.merge(area,left_on='Country',right_on='Country')
cia
# Out:
#      Rank                   Country  metric tonnes of CO2 Date of Information  \
# 0       1                     China           10773248000           2019 est.
# 1       2             United States            5144361000           2019 est.
# 2       3                     India            2314738000           2019 est.
# 3       4                    Russia            1848070000           2019 est.
# 4       5                     Japan            1103234000           2019 est.
# ..    ...                       ...                   ...                 ...
# 186   211                     Nauru                 66000           2019 est.
# 187   213                Montserrat                 33000           2019 est.
# 188   216                      Niue                  8000           2019 est.
# 189   217  Northern Mariana Islands                     0           2019 est.
# 190   218                    Tuvalu                     0           2019 est.
#
#        #  Population  (2023) Yearly  Change  Net  Change  Density  (P/Km²)  \
# 0      2          1425671352        -0.02 %      -215985               152
# 1      3           339996563         0.50 %      1706706                37
# 2      1          1428627663         0.81 %     11454490               481
# 3      9           144444359        -0.19 %      -268955                 9
# 4     12           123294513        -0.53 %      -657179               338
# ..   ...                 ...            ...          ...               ...
# 186  224               12780         0.88 %          112               639
# 187  230                4386        -0.09 %           -4                44
# 188  232                1935         0.05 %            1                 7
# 189  208               49796         0.49 %          245               108
# 190  226               11396         0.74 %           84               380
#
#      Land Area  (Km²)  Migrants  (net)  Fert.  Rate  Med.  Age Urban  Pop %  \
# 0             9388211          -310220          1.2       39.0         65 %
# 1             9147420           999700          1.7       38.0         83 %
# 2             2973190          -486136          2.0       28.0         36 %
# 3            16376870          -136414          1.5       39.0         75 %
# 4              364555            99994          1.3       49.0         94 %
# ..                ...              ...          ...        ...          ...
# 186                20             -140          3.4       20.0         88 %
# 187               100                0          1.6       44.0         11 %
# 188               260                0          2.4       36.0         41 %
# 189               460              -50          2.1       38.0         N.A.
# 190                30              -60          3.1       25.0         69 %
#
#     World  Share
# 0        17.72 %
# 1         4.23 %
# 2        17.76 %
# 3         1.80 %
# 4         1.53 %
# ..           ...
# 186       0.00 %
# 187       0.00 %
# 188       0.00 %
# 189       0.00 %
# 190       0.00 %
#
# [191 rows x 15 columns]

# %%
tar=cia.merge(precipitation,left_on='Country',right_on='Country')
tar
# Out:
#      Rank_x                   Country  metric tonnes of CO2  \
# 0         1                     China           10773248000
# 1         2             United States            5144361000
# 2         3                     India            2314738000
# 3         4                    Russia            1848070000
# 4         5                     Japan            1103234000
# ..      ...                       ...                   ...
# 156     195                   Comoros                326000
# 157     196                   Grenada                316000
# 158     198  Central African Republic                285000
# 159     201                   Vanuatu                225000
# 160     203                  Dominica                182000
#
#     Date of Information    #  Population  (2023) Yearly  Change  Net  Change  \
# 0             2019 est.    2          1425671352        -0.02 %      -215985
# 1             2019 est.    3           339996563         0.50 %      1706706
# 2             2019 est.    1          1428627663         0.81 %     11454490
# 3             2019 est.    9           144444359        -0.19 %      -268955
# 4             2019 est.   12           123294513        -0.53 %      -657179
# ..                  ...  ...                 ...            ...          ...
# 156           2019 est.  163              852075         1.83 %        15301
# 157           2019 est.  194              126183         0.59 %          745
# 158           2019 est.  117             5742315         2.92 %       163171
# 159           2019 est.  183              334506         2.38 %         7766
# 160           2019 est.  203               73040         0.42 %          303
#
#      Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  Fert.  Rate  \
# 0                 152           9388211          -310220          1.2
# 1                  37           9147420           999700          1.7
# 2                 481           2973190          -486136          2.0
# 3                   9          16376870          -136414          1.5
# 4                 338            364555            99994          1.3
# ..                ...               ...              ...          ...
# 156               458              1861            -2000          3.8
# 157               371               340             -200          2.0
# 158                 9            622980           -14716          5.8
# 159                27             12190                0          3.7
# 160                97               750              -40          1.6
#
#      Med.  Age Urban  Pop % World  Share  Rank_y   Value  Year
# 0         39.0         65 %      17.72 %     121   645.0  2017
# 1         38.0         83 %       4.23 %     110   715.0  2017
# 2         28.0         36 %      17.76 %      86  1083.0  2017
# 3         39.0         75 %       1.80 %     144   460.0  2017
# 4         49.0         94 %       1.53 %      47  1668.0  2017
# ..         ...          ...          ...     ...     ...   ...
# 156       20.0         33 %       0.01 %      97   900.0  2017
# 157       32.0         32 %       0.00 %      17  2350.0  2014
# 158       15.0         40 %       0.07 %      67  1343.0  2017
# 159       20.0         24 %       0.00 %      33  2000.0  2017
# 160       32.0         75 %       0.00 %      28  2083.0  2017
#
# [161 rows x 18 columns]

# %%
import os
country_isosLink='https://github.com/IntroCDE2023/EVALUACION-01/raw/main/country_isos.xlsx'
country_isos=pd.read_excel(os.path.join('country_isos.xlsx'))

# %%
country_isos
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %%
#Error
eva=tar.merge(country_isos,left_on='Country',right_on='Country')
eva
# Out:
# Empty DataFrame
# Columns: [Rank_x, Country, metric tonnes of CO2, Date of Information, #, Population  (2023), Yearly  Change, Net  Change, Density  (P/Km²), Land Area  (Km²), Migrants  (net), Fert.  Rate, Med.  Age, Urban  Pop %, World  Share, Rank_y, Value, Year, Officialstatename, InternetccTLD, iso2, iso3]
# Index: []
#
# [0 rows x 22 columns]

# %%
tar['Country']=tar['Country'].str.upper()

# %%
tar
# Out:
#      Rank_x                   Country  metric tonnes of CO2  \
# 0         1                     CHINA           10773248000
# 1         2             UNITED STATES            5144361000
# 2         3                     INDIA            2314738000
# 3         4                    RUSSIA            1848070000
# 4         5                     JAPAN            1103234000
# ..      ...                       ...                   ...
# 156     195                   COMOROS                326000
# 157     196                   GRENADA                316000
# 158     198  CENTRAL AFRICAN REPUBLIC                285000
# 159     201                   VANUATU                225000
# 160     203                  DOMINICA                182000
#
#     Date of Information    #  Population  (2023) Yearly  Change  Net  Change  \
# 0             2019 est.    2          1425671352        -0.02 %      -215985
# 1             2019 est.    3           339996563         0.50 %      1706706
# 2             2019 est.    1          1428627663         0.81 %     11454490
# 3             2019 est.    9           144444359        -0.19 %      -268955
# 4             2019 est.   12           123294513        -0.53 %      -657179
# ..                  ...  ...                 ...            ...          ...
# 156           2019 est.  163              852075         1.83 %        15301
# 157           2019 est.  194              126183         0.59 %          745
# 158           2019 est.  117             5742315         2.92 %       163171
# 159           2019 est.  183              334506         2.38 %         7766
# 160           2019 est.  203               73040         0.42 %          303
#
#      Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  Fert.  Rate  \
# 0                 152           9388211          -310220          1.2
# 1                  37           9147420           999700          1.7
# 2                 481           2973190          -486136          2.0
# 3                   9          16376870          -136414          1.5
# 4                 338            364555            99994          1.3
# ..                ...               ...              ...          ...
# 156               458              1861            -2000          3.8
# 157               371               340             -200          2.0
# 158                 9            622980           -14716          5.8
# 159                27             12190                0          3.7
# 160                97               750              -40          1.6
#
#      Med.  Age Urban  Pop % World  Share  Rank_y   Value  Year
# 0         39.0         65 %      17.72 %     121   645.0  2017
# 1         38.0         83 %       4.23 %     110   715.0  2017
# 2         28.0         36 %      17.76 %      86  1083.0  2017
# 3         39.0         75 %       1.80 %     144   460.0  2017
# 4         49.0         94 %       1.53 %      47  1668.0  2017
# ..         ...          ...          ...     ...     ...   ...
# 156       20.0         33 %       0.01 %      97   900.0  2017
# 157       32.0         32 %       0.00 %      17  2350.0  2014
# 158       15.0         40 %       0.07 %      67  1343.0  2017
# 159       20.0         24 %       0.00 %      33  2000.0  2017
# 160       32.0         75 %       0.00 %      28  2083.0  2017
#
# [161 rows x 18 columns]

# %%
eva=tar.merge(country_isos,left_on='Country',right_on='Country')
eva
# Out:
#      Rank_x          Country  metric tonnes of CO2 Date of Information    #  \
# 0         1            CHINA           10773248000           2019 est.    2
# 1         3            INDIA            2314738000           2019 est.    1
# 2         5            JAPAN            1103234000           2019 est.   12
# 3         6          GERMANY             726881000           2019 est.   19
# 4         9           CANADA             612084000           2019 est.   38
# ..      ...              ...                   ...                 ...  ...
# 131     189      TIMOR-LESTE                538000           2019 est.  155
# 132     191            SAMOA                355000           2019 est.  189
# 133     193    GUINEA-BISSAU                342000           2019 est.  148
# 134     194  SOLOMON ISLANDS                333000           2019 est.  166
# 135     196          GRENADA                316000           2019 est.  194
#
#      Population  (2023) Yearly  Change  Net  Change  Density  (P/Km²)  \
# 0            1425671352        -0.02 %      -215985               152
# 1            1428627663         0.81 %     11454490               481
# 2             123294513        -0.53 %      -657179               338
# 3              83294633        -0.09 %       -75210               239
# 4              38781291         0.85 %       326964                 4
# ..                  ...            ...          ...               ...
# 131             1360596         1.44 %        19300                91
# 132              225681         1.48 %         3299                80
# 133             2150842         2.15 %        45276                76
# 134              740424         2.23 %        16151                26
# 135              126183         0.59 %          745               371
#
#      Land Area  (Km²)  ...  Med.  Age  Urban  Pop %  World  Share Rank_y  \
# 0             9388211  ...       39.0          65 %       17.72 %    121
# 1             2973190  ...       28.0          36 %       17.76 %     86
# 2              364555  ...       49.0          94 %        1.53 %     47
# 3              348560  ...       45.0          77 %        1.04 %    112
# 4             9093510  ...       41.0          81 %        0.48 %    137
# ..                ...  ...        ...           ...           ...    ...
# 131             14870  ...       21.0          35 %        0.02 %     58
# 132              2830  ...       21.0          16 %        0.00 %      7
# 133             28120  ...       19.0          45 %        0.03 %     53
# 134             27990  ...       19.0          24 %        0.01 %      4
# 135               340  ...       32.0          32 %        0.00 %     17
#
#       Value  Year                       Officialstatename  InternetccTLD iso2  \
# 0     645.0  2017          The People's Republic of China            .cn   CN
# 1    1083.0  2017                   The Republic of India            .in   IN
# 2    1668.0  2017                                   Japan            .jp   JP
# 3     700.0  2017         The Federal Republic of Germany            .de   DE
# 4     537.0  2017                                  Canada            .ca   CA
# ..      ...   ...                                     ...            ...  ...
# 131  1500.0  2017  The Democratic Republic of Timor-Leste            .tl   TL
# 132  2880.0  2017          The Independent State of Samoa            .ws   WS
# 133  1577.0  2017           The Republic of Guinea-Bissau            .gw   GW
# 134  3028.0  2017                     The Solomon Islands            .sb   SB
# 135  2350.0  2014                                 Grenada            .gd   GD
#
#     iso3
# 0    CHN
# 1    IND
# 2    JPN
# 3    DEU
# 4    CAN
# ..   ...
# 131  TLS
# 132  WSM
# 133  GNB
# 134  SLB
# 135  GRD
#
# [136 rows x 22 columns]

# %%
eva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank_x                136 non-null    int64
#  1   Country               136 non-null    object
#  2   metric tonnes of CO2  136 non-null    int64
#  3   Date of Information   136 non-null    object
#  4   #                     136 non-null    int64
#  5   Population  (2023)    136 non-null    int64
#  6   Yearly  Change        136 non-null    object
#  7   Net  Change           136 non-null    int64
#  8   Density  (P/Km²)      136 non-null    int64
#  9   Land Area  (Km²)      136 non-null    int64
#  10  Migrants  (net)       136 non-null    int64
#  11  Fert.  Rate           136 non-null    float64
#  12  Med.  Age             136 non-null    float64
#  13  Urban  Pop %          136 non-null    object
#  14  World  Share          136 non-null    object
#  15  Rank_y                136 non-null    int64
#  16  Value                 136 non-null    float64
#  17  Year                  136 non-null    int64
#  18  Officialstatename     136 non-null    object
#  19  InternetccTLD         136 non-null    object
#  20  iso2                  135 non-null    object
#  21  iso3                  136 non-null    object
# dtypes: float64(3), int64(10), object(9)
# memory usage: 23.5+ KB

# %%
eva=eva.astype(object)

# %%
eva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank_x                136 non-null    object
#  1   Country               136 non-null    object
#  2   metric tonnes of CO2  136 non-null    object
#  3   Date of Information   136 non-null    object
#  4   #                     136 non-null    object
#  5   Population  (2023)    136 non-null    object
#  6   Yearly  Change        136 non-null    object
#  7   Net  Change           136 non-null    object
#  8   Density  (P/Km²)      136 non-null    object
#  9   Land Area  (Km²)      136 non-null    object
#  10  Migrants  (net)       136 non-null    object
#  11  Fert.  Rate           136 non-null    object
#  12  Med.  Age             136 non-null    object
#  13  Urban  Pop %          136 non-null    object
#  14  World  Share          136 non-null    object
#  15  Rank_y                136 non-null    object
#  16  Value                 136 non-null    object
#  17  Year                  136 non-null    object
#  18  Officialstatename     136 non-null    object
#  19  InternetccTLD         136 non-null    object
#  20  iso2                  135 non-null    object
#  21  iso3                  136 non-null    object
# dtypes: object(22)
# memory usage: 23.5+ KB

# %%
columnas_a_eliminar=['Rank_x','Date of Information','#','Rank_y','Year',]

# %%
columnas_existentes = [col for col in columnas_a_eliminar if col in eva.columns]

# %%
eva=eva.drop(columnas_a_eliminar,axis=1)

# %%
eva
# Out:
#              Country metric tonnes of CO2 Population  (2023) Yearly  Change  \
# 0              CHINA          10773248000         1425671352        -0.02 %
# 1              INDIA           2314738000         1428627663         0.81 %
# 2              JAPAN           1103234000          123294513        -0.53 %
# 3            GERMANY            726881000           83294633        -0.09 %
# 4             CANADA            612084000           38781291         0.85 %
# ..               ...                  ...                ...            ...
# 131      TIMOR-LESTE               538000            1360596         1.44 %
# 132            SAMOA               355000             225681         1.48 %
# 133    GUINEA-BISSAU               342000            2150842         2.15 %
# 134  SOLOMON ISLANDS               333000             740424         2.23 %
# 135          GRENADA               316000             126183         0.59 %
#
#     Net  Change Density  (P/Km²) Land Area  (Km²) Migrants  (net) Fert.  Rate  \
# 0       -215985              152          9388211         -310220         1.2
# 1      11454490              481          2973190         -486136         2.0
# 2       -657179              338           364555           99994         1.3
# 3        -75210              239           348560          155751         1.5
# 4        326964                4          9093510          249746         1.5
# ..          ...              ...              ...             ...         ...
# 131       19300               91            14870           -5000         3.0
# 132        3299               80             2830           -1500         3.8
# 133       45276               76            28120           -1400         3.8
# 134       16151               26            27990           -1600         3.9
# 135         745              371              340            -200         2.0
#
#     Med.  Age Urban  Pop % World  Share   Value  \
# 0        39.0         65 %      17.72 %   645.0
# 1        28.0         36 %      17.76 %  1083.0
# 2        49.0         94 %       1.53 %  1668.0
# 3        45.0         77 %       1.04 %   700.0
# 4        41.0         81 %       0.48 %   537.0
# ..        ...          ...          ...     ...
# 131      21.0         35 %       0.02 %  1500.0
# 132      21.0         16 %       0.00 %  2880.0
# 133      19.0         45 %       0.03 %  1577.0
# 134      19.0         24 %       0.01 %  3028.0
# 135      32.0         32 %       0.00 %  2350.0
#
#                           Officialstatename InternetccTLD iso2 iso3
# 0            The People's Republic of China           .cn   CN  CHN
# 1                     The Republic of India           .in   IN  IND
# 2                                     Japan           .jp   JP  JPN
# 3           The Federal Republic of Germany           .de   DE  DEU
# 4                                    Canada           .ca   CA  CAN
# ..                                      ...           ...  ...  ...
# 131  The Democratic Republic of Timor-Leste           .tl   TL  TLS
# 132          The Independent State of Samoa           .ws   WS  WSM
# 133           The Republic of Guinea-Bissau           .gw   GW  GNB
# 134                     The Solomon Islands           .sb   SB  SLB
# 135                                 Grenada           .gd   GD  GRD
#
# [136 rows x 17 columns]

# %%
eva=eva.rename(columns=lambda x: x.strip() if isinstance(x, str) else x)

# %%
eva=eva.rename(columns=lambda x: x.strip().replace(' ', '_') if isinstance(x, str) else x)

# %%
eva
# Out:
#              Country metric_tonnes_of_CO2 Population__(2023) Yearly__Change  \
# 0              CHINA          10773248000         1425671352        -0.02 %
# 1              INDIA           2314738000         1428627663         0.81 %
# 2              JAPAN           1103234000          123294513        -0.53 %
# 3            GERMANY            726881000           83294633        -0.09 %
# 4             CANADA            612084000           38781291         0.85 %
# ..               ...                  ...                ...            ...
# 131      TIMOR-LESTE               538000            1360596         1.44 %
# 132            SAMOA               355000             225681         1.48 %
# 133    GUINEA-BISSAU               342000            2150842         2.15 %
# 134  SOLOMON ISLANDS               333000             740424         2.23 %
# 135          GRENADA               316000             126183         0.59 %
#
#     Net__Change Density__(P/Km²) Land_Area__(Km²) Migrants__(net) Fert.__Rate  \
# 0       -215985              152          9388211         -310220         1.2
# 1      11454490              481          2973190         -486136         2.0
# 2       -657179              338           364555           99994         1.3
# 3        -75210              239           348560          155751         1.5
# 4        326964                4          9093510          249746         1.5
# ..          ...              ...              ...             ...         ...
# 131       19300               91            14870           -5000         3.0
# 132        3299               80             2830           -1500         3.8
# 133       45276               76            28120           -1400         3.8
# 134       16151               26            27990           -1600         3.9
# 135         745              371              340            -200         2.0
#
#     Med.__Age Urban__Pop_% World__Share   Value  \
# 0        39.0         65 %      17.72 %   645.0
# 1        28.0         36 %      17.76 %  1083.0
# 2        49.0         94 %       1.53 %  1668.0
# 3        45.0         77 %       1.04 %   700.0
# 4        41.0         81 %       0.48 %   537.0
# ..        ...          ...          ...     ...
# 131      21.0         35 %       0.02 %  1500.0
# 132      21.0         16 %       0.00 %  2880.0
# 133      19.0         45 %       0.03 %  1577.0
# 134      19.0         24 %       0.01 %  3028.0
# 135      32.0         32 %       0.00 %  2350.0
#
#                           Officialstatename InternetccTLD iso2 iso3
# 0            The People's Republic of China           .cn   CN  CHN
# 1                     The Republic of India           .in   IN  IND
# 2                                     Japan           .jp   JP  JPN
# 3           The Federal Republic of Germany           .de   DE  DEU
# 4                                    Canada           .ca   CA  CAN
# ..                                      ...           ...  ...  ...
# 131  The Democratic Republic of Timor-Leste           .tl   TL  TLS
# 132          The Independent State of Samoa           .ws   WS  WSM
# 133           The Republic of Guinea-Bissau           .gw   GW  GNB
# 134                     The Solomon Islands           .sb   SB  SLB
# 135                                 Grenada           .gd   GD  GRD
#
# [136 rows x 17 columns]

# %%
columnas_a_eliminar=['Population__(2023)','Yearly__Change','Net__Change','Density__(P/Km²)','Migrants__(net)','Fert.__Rate','Med.__Age','Urban__Pop_%','World__Share']

# %%
columnas_existentes = [col for col in columnas_a_eliminar if col in eva.columns]

# %%
eva=eva.drop(columnas_a_eliminar,axis=1)

# %%
eva
# Out:
#              Country metric_tonnes_of_CO2 Land_Area__(Km²)   Value  \
# 0              CHINA          10773248000          9388211   645.0
# 1              INDIA           2314738000          2973190  1083.0
# 2              JAPAN           1103234000           364555  1668.0
# 3            GERMANY            726881000           348560   700.0
# 4             CANADA            612084000          9093510   537.0
# ..               ...                  ...              ...     ...
# 131      TIMOR-LESTE               538000            14870  1500.0
# 132            SAMOA               355000             2830  2880.0
# 133    GUINEA-BISSAU               342000            28120  1577.0
# 134  SOLOMON ISLANDS               333000            27990  3028.0
# 135          GRENADA               316000              340  2350.0
#
#                           Officialstatename InternetccTLD iso2 iso3
# 0            The People's Republic of China           .cn   CN  CHN
# 1                     The Republic of India           .in   IN  IND
# 2                                     Japan           .jp   JP  JPN
# 3           The Federal Republic of Germany           .de   DE  DEU
# 4                                    Canada           .ca   CA  CAN
# ..                                      ...           ...  ...  ...
# 131  The Democratic Republic of Timor-Leste           .tl   TL  TLS
# 132          The Independent State of Samoa           .ws   WS  WSM
# 133           The Republic of Guinea-Bissau           .gw   GW  GNB
# 134                     The Solomon Islands           .sb   SB  SLB
# 135                                 Grenada           .gd   GD  GRD
#
# [136 rows x 8 columns]

# %%
eva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               136 non-null    object
#  1   metric_tonnes_of_CO2  136 non-null    object
#  2   Land_Area__(Km²)      136 non-null    object
#  3   Value                 136 non-null    object
#  4   Officialstatename     136 non-null    object
#  5   InternetccTLD         136 non-null    object
#  6   iso2                  135 non-null    object
#  7   iso3                  136 non-null    object
# dtypes: object(8)
# memory usage: 8.6+ KB

# %%
nuevo_orden_columnas = ['Country','Officialstatename','InternetccTLD','iso2','iso3','Land_Area__(Km²)','metric_tonnes_of_CO2','Value']

# %%
eva=eva[nuevo_orden_columnas]

# %%
eva
# Out:
#              Country                       Officialstatename InternetccTLD  \
# 0              CHINA          The People's Republic of China           .cn
# 1              INDIA                   The Republic of India           .in
# 2              JAPAN                                   Japan           .jp
# 3            GERMANY         The Federal Republic of Germany           .de
# 4             CANADA                                  Canada           .ca
# ..               ...                                     ...           ...
# 131      TIMOR-LESTE  The Democratic Republic of Timor-Leste           .tl
# 132            SAMOA          The Independent State of Samoa           .ws
# 133    GUINEA-BISSAU           The Republic of Guinea-Bissau           .gw
# 134  SOLOMON ISLANDS                     The Solomon Islands           .sb
# 135          GRENADA                                 Grenada           .gd
#
#     iso2 iso3 Land_Area__(Km²) metric_tonnes_of_CO2   Value
# 0     CN  CHN          9388211          10773248000   645.0
# 1     IN  IND          2973190           2314738000  1083.0
# 2     JP  JPN           364555           1103234000  1668.0
# 3     DE  DEU           348560            726881000   700.0
# 4     CA  CAN          9093510            612084000   537.0
# ..   ...  ...              ...                  ...     ...
# 131   TL  TLS            14870               538000  1500.0
# 132   WS  WSM             2830               355000  2880.0
# 133   GW  GNB            28120               342000  1577.0
# 134   SB  SLB            27990               333000  3028.0
# 135   GD  GRD              340               316000  2350.0
#
# [136 rows x 8 columns]

# %%
eva
# Out:
#              Country                       Officialstatename InternetccTLD  \
# 0              CHINA          The People's Republic of China           .cn
# 1              INDIA                   The Republic of India           .in
# 2              JAPAN                                   Japan           .jp
# 3            GERMANY         The Federal Republic of Germany           .de
# 4             CANADA                                  Canada           .ca
# ..               ...                                     ...           ...
# 131      TIMOR-LESTE  The Democratic Republic of Timor-Leste           .tl
# 132            SAMOA          The Independent State of Samoa           .ws
# 133    GUINEA-BISSAU           The Republic of Guinea-Bissau           .gw
# 134  SOLOMON ISLANDS                     The Solomon Islands           .sb
# 135          GRENADA                                 Grenada           .gd
#
#     iso2 iso3 Land_Area__(Km²) metric_tonnes_of_CO2   Value
# 0     CN  CHN          9388211          10773248000   645.0
# 1     IN  IND          2973190           2314738000  1083.0
# 2     JP  JPN           364555           1103234000  1668.0
# 3     DE  DEU           348560            726881000   700.0
# 4     CA  CAN          9093510            612084000   537.0
# ..   ...  ...              ...                  ...     ...
# 131   TL  TLS            14870               538000  1500.0
# 132   WS  WSM             2830               355000  2880.0
# 133   GW  GNB            28120               342000  1577.0
# 134   SB  SLB            27990               333000  3028.0
# 135   GD  GRD              340               316000  2350.0
#
# [136 rows x 8 columns]

# %%
nuevos_nombres = ['Country','Officialstatename','InternetccTLD','iso2','iso3','Area(Km²)','CO2_emissions(ton)','Precipitation']

# %%
eva.columns=nuevos_nombres

# %%
eva
# Out:
#              Country                       Officialstatename InternetccTLD  \
# 0              CHINA          The People's Republic of China           .cn
# 1              INDIA                   The Republic of India           .in
# 2              JAPAN                                   Japan           .jp
# 3            GERMANY         The Federal Republic of Germany           .de
# 4             CANADA                                  Canada           .ca
# ..               ...                                     ...           ...
# 131      TIMOR-LESTE  The Democratic Republic of Timor-Leste           .tl
# 132            SAMOA          The Independent State of Samoa           .ws
# 133    GUINEA-BISSAU           The Republic of Guinea-Bissau           .gw
# 134  SOLOMON ISLANDS                     The Solomon Islands           .sb
# 135          GRENADA                                 Grenada           .gd
#
#     iso2 iso3 Area(Km²) CO2_emissions(ton) Precipitation
# 0     CN  CHN   9388211        10773248000         645.0
# 1     IN  IND   2973190         2314738000        1083.0
# 2     JP  JPN    364555         1103234000        1668.0
# 3     DE  DEU    348560          726881000         700.0
# 4     CA  CAN   9093510          612084000         537.0
# ..   ...  ...       ...                ...           ...
# 131   TL  TLS     14870             538000        1500.0
# 132   WS  WSM      2830             355000        2880.0
# 133   GW  GNB     28120             342000        1577.0
# 134   SB  SLB     27990             333000        3028.0
# 135   GD  GRD       340             316000        2350.0
#
# [136 rows x 8 columns]

# %%
eva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             136 non-null    object
#  1   Officialstatename   136 non-null    object
#  2   InternetccTLD       136 non-null    object
#  3   iso2                135 non-null    object
#  4   iso3                136 non-null    object
#  5   Area(Km²)           136 non-null    object
#  6   CO2_emissions(ton)  136 non-null    object
#  7   Precipitation       136 non-null    object
# dtypes: object(8)
# memory usage: 8.6+ KB

# %%
nombre_columna = 'Area(Km²)'

# %%
eva[nombre_columna] = eva[nombre_columna].astype('int64')

# %%
nombre_columna ='CO2_emissions(ton)'

# %%
eva[nombre_columna] = eva[nombre_columna].astype('int64')

# %%
nombre_columna ='Precipitation'

# %%
eva[nombre_columna] = eva[nombre_columna].astype('float64')

# %%
eva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             136 non-null    object
#  1   Officialstatename   136 non-null    object
#  2   InternetccTLD       136 non-null    object
#  3   iso2                135 non-null    object
#  4   iso3                136 non-null    object
#  5   Area(Km²)           136 non-null    int64
#  6   CO2_emissions(ton)  136 non-null    int64
#  7   Precipitation       136 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 8.6+ KB

# %%
eva
# Out:
#              Country                       Officialstatename InternetccTLD  \
# 0              CHINA          The People's Republic of China           .cn
# 1              INDIA                   The Republic of India           .in
# 2              JAPAN                                   Japan           .jp
# 3            GERMANY         The Federal Republic of Germany           .de
# 4             CANADA                                  Canada           .ca
# ..               ...                                     ...           ...
# 131      TIMOR-LESTE  The Democratic Republic of Timor-Leste           .tl
# 132            SAMOA          The Independent State of Samoa           .ws
# 133    GUINEA-BISSAU           The Republic of Guinea-Bissau           .gw
# 134  SOLOMON ISLANDS                     The Solomon Islands           .sb
# 135          GRENADA                                 Grenada           .gd
#
#     iso2 iso3  Area(Km²)  CO2_emissions(ton)  Precipitation
# 0     CN  CHN    9388211         10773248000          645.0
# 1     IN  IND    2973190          2314738000         1083.0
# 2     JP  JPN     364555          1103234000         1668.0
# 3     DE  DEU     348560           726881000          700.0
# 4     CA  CAN    9093510           612084000          537.0
# ..   ...  ...        ...                 ...            ...
# 131   TL  TLS      14870              538000         1500.0
# 132   WS  WSM       2830              355000         2880.0
# 133   GW  GNB      28120              342000         1577.0
# 134   SB  SLB      27990              333000         3028.0
# 135   GD  GRD        340              316000         2350.0
#
# [136 rows x 8 columns]

# %%
print(eva.isnull().sum())
# Out:
# Country               0
# Officialstatename     0
# InternetccTLD         0
# iso2                  1
# iso3                  0
# Area(Km²)             0
# CO2_emissions(ton)    0
# Precipitation         0
# dtype: int64

# %%
print(eva.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             136 non-null    object
#  1   Officialstatename   136 non-null    object
#  2   InternetccTLD       136 non-null    object
#  3   iso2                135 non-null    object
#  4   iso3                136 non-null    object
#  5   Area(Km²)           136 non-null    int64
#  6   CO2_emissions(ton)  136 non-null    int64
#  7   Precipitation       136 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 8.6+ KB
# None

# %%
eva = eva.dropna()

# %%
eva
# Out:
#              Country                       Officialstatename InternetccTLD  \
# 0              CHINA          The People's Republic of China           .cn
# 1              INDIA                   The Republic of India           .in
# 2              JAPAN                                   Japan           .jp
# 3            GERMANY         The Federal Republic of Germany           .de
# 4             CANADA                                  Canada           .ca
# ..               ...                                     ...           ...
# 131      TIMOR-LESTE  The Democratic Republic of Timor-Leste           .tl
# 132            SAMOA          The Independent State of Samoa           .ws
# 133    GUINEA-BISSAU           The Republic of Guinea-Bissau           .gw
# 134  SOLOMON ISLANDS                     The Solomon Islands           .sb
# 135          GRENADA                                 Grenada           .gd
#
#     iso2 iso3  Area(Km²)  CO2_emissions(ton)  Precipitation
# 0     CN  CHN    9388211         10773248000          645.0
# 1     IN  IND    2973190          2314738000         1083.0
# 2     JP  JPN     364555          1103234000         1668.0
# 3     DE  DEU     348560           726881000          700.0
# 4     CA  CAN    9093510           612084000          537.0
# ..   ...  ...        ...                 ...            ...
# 131   TL  TLS      14870              538000         1500.0
# 132   WS  WSM       2830              355000         2880.0
# 133   GW  GNB      28120              342000         1577.0
# 134   SB  SLB      27990              333000         3028.0
# 135   GD  GRD        340              316000         2350.0
#
# [135 rows x 8 columns]

# %%
print(eva.isnull().sum())
# Out:
# Country               0
# Officialstatename     0
# InternetccTLD         0
# iso2                  0
# iso3                  0
# Area(Km²)             0
# CO2_emissions(ton)    0
# Precipitation         0
# dtype: int64

# %%
eva = eva.drop_duplicates()

# %%
eva
# Out:
#              Country                       Officialstatename InternetccTLD  \
# 0              CHINA          The People's Republic of China           .cn
# 1              INDIA                   The Republic of India           .in
# 2              JAPAN                                   Japan           .jp
# 3            GERMANY         The Federal Republic of Germany           .de
# 4             CANADA                                  Canada           .ca
# ..               ...                                     ...           ...
# 131      TIMOR-LESTE  The Democratic Republic of Timor-Leste           .tl
# 132            SAMOA          The Independent State of Samoa           .ws
# 133    GUINEA-BISSAU           The Republic of Guinea-Bissau           .gw
# 134  SOLOMON ISLANDS                     The Solomon Islands           .sb
# 135          GRENADA                                 Grenada           .gd
#
#     iso2 iso3  Area(Km²)  CO2_emissions(ton)  Precipitation
# 0     CN  CHN    9388211         10773248000          645.0
# 1     IN  IND    2973190          2314738000         1083.0
# 2     JP  JPN     364555          1103234000         1668.0
# 3     DE  DEU     348560           726881000          700.0
# 4     CA  CAN    9093510           612084000          537.0
# ..   ...  ...        ...                 ...            ...
# 131   TL  TLS      14870              538000         1500.0
# 132   WS  WSM       2830              355000         2880.0
# 133   GW  GNB      28120              342000         1577.0
# 134   SB  SLB      27990              333000         3028.0
# 135   GD  GRD        340              316000         2350.0
#
# [135 rows x 8 columns]
