# %%
#Fuentes de referencia
co2Link='https://www.cia.gov/the-world-factbook/field/carbon-dioxide-emissions/country-comparison/'
areaLink='https://www.worldometers.info/world-population/population-by-country/'
precipitationLink='https://www.indexmundi.com/facts/indicators/AG.LND.PRCP.MM/rankings'

import pandas as pd
co2List=pd.read_html(co2Link,header=0,flavor='bs4')
areaList=pd.read_html(areaLink,header=0,flavor='bs4')
precipitationList=pd.read_html(precipitationLink,header=0,flavor='bs4')

# %%
co2=co2List[0]
area=areaList[0]
precipitation=precipitationList[0]

co2
# Out:
#      Rank                                        Country  \
# 0       1                                          China
# 1       2                                  United States
# 2       3                                          India
# 3       4                                         Russia
# 4       5                                          Japan
# ..    ...                                            ...
# 213   214                                     Antarctica
# 214   215  Saint Helena, Ascension, and Tristan da Cunha
# 215   216                                           Niue
# 216   217                       Northern Mariana Islands
# 217   218                                         Tuvalu
#
#      metric tonnes of CO2 Date of Information
# 0             10773248000           2019 est.
# 1              5144361000           2019 est.
# 2              2314738000           2019 est.
# 3              1848070000           2019 est.
# ...

# %%
co2.shape,area.shape,precipitation.shape
# Out:
# ((218, 4), (234, 12), (179, 4))

# %%
co2.columns,area.columns,precipitation.columns
# Out:
# (Index(['Rank', 'Country', 'metric tonnes of CO2', 'Date of Information'], dtype='object'),
#  Index(['#', 'Country (or dependency)', 'Population  (2023)', 'Yearly  Change',
#         'Net  Change', 'Density  (P/Km²)', 'Land Area  (Km²)',
#         'Migrants  (net)', 'Fert.  Rate', 'Med.  Age', 'Urban  Pop %',
#         'World  Share'],
#        dtype='object'),
#  Index(['Rank', 'Country', 'Value', 'Year'], dtype='object'))

# %%
area.rename(columns={'Country (or dependency)': 'Country'}, inplace=True)

# %%
area
# Out:
#        #           Country  Population  (2023) Yearly  Change  Net  Change  \
# 0      1             India          1428627663         0.81 %     11454490
# 1      2             China          1425671352        -0.02 %      -215985
# 2      3     United States           339996563         0.50 %      1706706
# 3      4         Indonesia           277534122         0.74 %      2032783
# 4      5          Pakistan           240485658         1.98 %      4660796
# ..   ...               ...                 ...            ...          ...
# 229  230        Montserrat                4386        -0.09 %           -4
# 230  231  Falkland Islands                3791         0.29 %           11
# 231  232              Niue                1935         0.05 %            1
# 232  233           Tokelau                1893         1.18 %           22
# 233  234          Holy See                 518         1.57 %            8
#
# ...

# %%
co2.merge(area,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (191, 15)

# %%
co2.merge(area,how='left',left_on='Country',right_on='Country').shape
# Out:
# (218, 15)

# %%
co2.merge(area,how='outer',left_on='Country',right_on='Country').shape
# Out:
# (261, 15)

# %%
co2.merge(precipitation,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (161, 7)

# %%
co2.merge(precipitation,how='left',left_on='Country',right_on='Country').shape
# Out:
# (218, 7)

# %%
co2.merge(precipitation,how='outer',left_on='Country',right_on='Country').shape
# Out:
# (236, 7)

# %%
area.merge(precipitation,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (165, 15)

# %%
area.merge(precipitation,how='left',left_on='Country',right_on='Country').shape
# Out:
# (234, 15)

# %%
area.merge(precipitation,how='outer',left_on='Country',right_on='Country').shape
# Out:
# (248, 15)

# %%
onlyco2=set(co2.Country)-set(area.Country)
onlyco2
# Out:
# {'Antarctica',
#  'Bahamas, The',
#  'Burma',
#  'Congo, Democratic Republic of the',
#  'Congo, Republic of the',
#  "Cote d'Ivoire",
#  'Czechia',
#  'Falkland Islands (Islas Malvinas)',
#  'Faroe Islands',
#  'Gambia, The',
#  'Gaza Strip',
#  'Jersey',
#  'Korea, North',
#  'Korea, South',
#  'Kosovo',
#  'Macau',
#  'Micronesia, Federated States of',
#  'Saint Helena, Ascension, and Tristan da Cunha',
#  'Saint Kitts and Nevis',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Sao Tome and Principe',
#  'Turkey (Turkiye)',
#  'Turks and Caicos Islands',
#  'Virgin Islands',
#  'Wake Island',
#  'West Bank'}

# %%
onlyarea=set(area.Country)-set(co2.Country)
onlyarea
# Out:
# {'Andorra',
#  'Anguilla',
#  'Bahamas',
#  'Caribbean Netherlands',
#  'Congo',
#  'Curaçao',
#  'Czech Republic (Czechia)',
#  "Côte d'Ivoire",
#  'DR Congo',
#  'Faeroe Islands',
#  'Falkland Islands',
#  'French Guiana',
#  'Gambia',
#  'Guadeloupe',
#  'Holy See',
#  'Isle of Man',
#  'Liechtenstein',
#  'Macao',
#  'Martinique',
#  'Mayotte',
#  'Micronesia',
#  'Monaco',
#  'Myanmar',
#  'North Korea',
#  'Palau',
#  'Réunion',
#  'Saint Barthelemy',
#  'Saint Helena',
#  'Saint Kitts & Nevis',
#  'Saint Martin',
#  'Saint Pierre & Miquelon',
#  'San Marino',
#  'Sao Tome & Principe',
#  'Sint Maarten',
#  'South Korea',
#  'St. Vincent & Grenadines',
#  'State of Palestine',
#  'Tokelau',
#  'Turkey',
#  'Turks and Caicos',
#  'U.S. Virgin Islands',
#  'Wallis & Futuna',
#  'Western Sahara'}

# %%
set(co2.Country)-set(precipitation.Country)
# Out:
# {'American Samoa',
#  'Antarctica',
#  'Aruba',
#  'Bahamas, The',
#  'Bermuda',
#  'British Virgin Islands',
#  'Burma',
#  'Cayman Islands',
#  'Congo, Democratic Republic of the',
#  'Congo, Republic of the',
#  'Cook Islands',
#  "Cote d'Ivoire",
#  'Czechia',
#  'Falkland Islands (Islas Malvinas)',
#  'Faroe Islands',
#  'French Polynesia',
#  'Gambia, The',
#  'Gaza Strip',
#  'Gibraltar',
#  'Greenland',
#  'Guam',
#  'Hong Kong',
#  'Jersey',
#  'Kiribati',
#  'Korea, North',
#  'Korea, South',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Laos',
#  'Macau',
#  'Maldives',
#  'Marshall Islands',
#  'Micronesia, Federated States of',
#  'Montenegro',
#  'Montserrat',
#  'Nauru',
#  'New Caledonia',
#  'Niue',
#  'Northern Mariana Islands',
#  'Saint Helena, Ascension, and Tristan da Cunha',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Sao Tome and Principe',
#  'Serbia',
#  'Slovakia',
#  'South Sudan',
# ...

# %%
set(precipitation.Country)-set(co2.Country)
# Out:
# {'Congo',
#  'Czech Republic',
#  "Côte d'Ivoire",
#  "Dem. People's Rep. Korea",
#  'Dem. Rep. Congo',
#  'Korea',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Myanmar',
#  'Slovak Republic',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Syrian Arab Republic',
#  'São Tomé and Principe',
#  'The Bahamas',
#  'The Gambia',
#  'Turkey'}

# %%
set(precipitation.Country)-set(area.Country)
# Out:
# {'Czech Republic',
#  "Dem. People's Rep. Korea",
#  'Dem. Rep. Congo',
#  'Korea',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Slovak Republic',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Syrian Arab Republic',
#  'São Tomé and Principe',
#  'The Bahamas',
#  'The Gambia'}

# %%
set(area.Country)-set(precipitation.Country)
# Out:
# {'American Samoa',
#  'Andorra',
#  'Anguilla',
#  'Aruba',
#  'Bahamas',
#  'Bermuda',
#  'British Virgin Islands',
#  'Caribbean Netherlands',
#  'Cayman Islands',
#  'Cook Islands',
#  'Curaçao',
#  'Czech Republic (Czechia)',
#  'DR Congo',
#  'Faeroe Islands',
#  'Falkland Islands',
#  'French Guiana',
#  'French Polynesia',
#  'Gambia',
#  'Gibraltar',
#  'Greenland',
#  'Guadeloupe',
#  'Guam',
#  'Holy See',
#  'Hong Kong',
#  'Isle of Man',
#  'Kiribati',
#  'Kyrgyzstan',
#  'Laos',
#  'Liechtenstein',
#  'Macao',
#  'Maldives',
#  'Marshall Islands',
#  'Martinique',
#  'Mayotte',
#  'Micronesia',
#  'Monaco',
#  'Montenegro',
#  'Montserrat',
#  'Nauru',
#  'New Caledonia',
#  'Niue',
#  'North Korea',
#  'Northern Mariana Islands',
#  'Palau',
#  'Réunion',
#  'Saint Barthelemy',
#  'Saint Helena',
#  'Saint Kitts & Nevis',
#  'Saint Lucia',
#  'Saint Martin',
#  'Saint Pierre & Miquelon',
#  'San Marino',
#  'Sao Tome & Principe',
#  'Serbia',
#  'Sint Maarten',
# ...

# %%
cia=co2.merge(area,left_on='Country',right_on='Country')
cia
# Out:
#      Rank                   Country  metric tonnes of CO2 Date of Information  \
# 0       1                     China           10773248000           2019 est.
# 1       2             United States            5144361000           2019 est.
# 2       3                     India            2314738000           2019 est.
# 3       4                    Russia            1848070000           2019 est.
# 4       5                     Japan            1103234000           2019 est.
# ..    ...                       ...                   ...                 ...
# 186   211                     Nauru                 66000           2019 est.
# 187   213                Montserrat                 33000           2019 est.
# 188   216                      Niue                  8000           2019 est.
# 189   217  Northern Mariana Islands                     0           2019 est.
# 190   218                    Tuvalu                     0           2019 est.
#
# ...

# %%
from thefuzz import process as fz
[(f,fz.extractOne(f,onlyco2)) for f in sorted(onlyarea)]
# Out:
# [('Andorra', ('Korea, North', 51)),
#  ('Anguilla', ('Falkland Islands (Islas Malvinas)', 56)),
#  ('Bahamas', ('Bahamas, The', 90)),
#  ('Caribbean Netherlands', ('West Bank', 57)),
#  ('Congo', ('Congo, Republic of the', 90)),
#  ('Curaçao', ('Burma', 55)),
#  ('Czech Republic (Czechia)', ('Czechia', 90)),
#  ("Côte d'Ivoire", ("Cote d'Ivoire", 96)),
#  ('DR Congo', ('Congo, Republic of the', 86)),
#  ('Faeroe Islands', ('Faroe Islands', 96)),
#  ('Falkland Islands', ('Falkland Islands (Islas Malvinas)', 90)),
#  ('French Guiana', ('Faroe Islands', 54)),
#  ('Gambia', ('Gambia, The', 90)),
#  ('Guadeloupe', ('Saint Pierre and Miquelon', 51)),
#  ('Holy See', ('Saint Helena, Ascension, and Tristan da Cunha', 43)),
#  ('Isle of Man', ('Congo, Republic of the', 86)),
#  ('Liechtenstein', ('Jersey', 45)),
#  ('Macao', ('Macau', 80)),
#  ('Martinique', ('Saint Pierre and Miquelon', 54)),
#  ('Mayotte', ('Sao Tome and Principe', 49)),
# ...

# %%
[(f,fz.extractOne(f ,onlyco2)) for f in sorted(onlyarea)
 if fz.extractOne(f ,onlyco2)[1]>=87]
# Out:
# [('Bahamas', ('Bahamas, The', 90)),
#  ('Congo', ('Congo, Republic of the', 90)),
#  ('Czech Republic (Czechia)', ('Czechia', 90)),
#  ("Côte d'Ivoire", ("Cote d'Ivoire", 96)),
#  ('Faeroe Islands', ('Faroe Islands', 96)),
#  ('Falkland Islands', ('Falkland Islands (Islas Malvinas)', 90)),
#  ('Gambia', ('Gambia, The', 90)),
#  ('Micronesia', ('Micronesia, Federated States of', 90)),
#  ('North Korea', ('Korea, North', 95)),
#  ('Saint Helena', ('Saint Helena, Ascension, and Tristan da Cunha', 90)),
#  ('Saint Kitts & Nevis', ('Saint Kitts and Nevis', 95)),
#  ('Saint Pierre & Miquelon', ('Saint Pierre and Miquelon', 95)),
#  ('Sao Tome & Principe', ('Sao Tome and Principe', 95)),
#  ('South Korea', ('Korea, South', 95)),
#  ('St. Vincent & Grenadines', ('Saint Vincent and the Grenadines', 87)),
#  ('Turkey', ('Turkey (Turkiye)', 90)),
#  ('Turks and Caicos', ('Turks and Caicos Islands', 90)),
#  ('U.S. Virgin Islands', ('Virgin Islands', 95))]

# %%
cambioco2yarea = {f:fz.extractOne(f, onlyco2)[0] 
                 for f in sorted(onlyarea)
                 if fz.extractOne(f, onlyco2)[1] >=87}
cambioco2yarea
# Out:
# {'Bahamas': 'Bahamas, The',
#  'Congo': 'Congo, Republic of the',
#  'Czech Republic (Czechia)': 'Czechia',
#  "Côte d'Ivoire": "Cote d'Ivoire",
#  'Faeroe Islands': 'Faroe Islands',
#  'Falkland Islands': 'Falkland Islands (Islas Malvinas)',
#  'Gambia': 'Gambia, The',
#  'Micronesia': 'Micronesia, Federated States of',
#  'North Korea': 'Korea, North',
#  'Saint Helena': 'Saint Helena, Ascension, and Tristan da Cunha',
#  'Saint Kitts & Nevis': 'Saint Kitts and Nevis',
#  'Saint Pierre & Miquelon': 'Saint Pierre and Miquelon',
#  'Sao Tome & Principe': 'Sao Tome and Principe',
#  'South Korea': 'Korea, South',
#  'St. Vincent & Grenadines': 'Saint Vincent and the Grenadines',
#  'Turkey': 'Turkey (Turkiye)',
#  'Turks and Caicos': 'Turks and Caicos Islands',
#  'U.S. Virgin Islands': 'Virgin Islands'}

# %%
co2['Country'].replace(cambioco2yarea, inplace=True)
co2
# Out:
#      Rank                                        Country  \
# 0       1                                          China
# 1       2                                  United States
# 2       3                                          India
# 3       4                                         Russia
# 4       5                                          Japan
# ..    ...                                            ...
# 213   214                                     Antarctica
# 214   215  Saint Helena, Ascension, and Tristan da Cunha
# 215   216                                           Niue
# 216   217                       Northern Mariana Islands
# 217   218                                         Tuvalu
#
#      metric tonnes of CO2 Date of Information
# 0             10773248000           2019 est.
# 1              5144361000           2019 est.
# 2              2314738000           2019 est.
# 3              1848070000           2019 est.
# ...

# %%
onlyco2=set(co2.Country)-set(area.Country)
onlyco2=set(area.Country)-set(co2.Country)
[(f,fz.extractOne(f, onlyco2)) for f in sorted(onlyarea)]
# Out:
# [('Andorra', ('Andorra', 100)),
#  ('Anguilla', ('Anguilla', 100)),
#  ('Bahamas', ('Bahamas', 100)),
#  ('Caribbean Netherlands', ('Caribbean Netherlands', 100)),
#  ('Congo', ('Congo', 100)),
#  ('Curaçao', ('Curaçao', 100)),
#  ('Czech Republic (Czechia)', ('Czech Republic (Czechia)', 100)),
#  ("Côte d'Ivoire", ("Côte d'Ivoire", 100)),
#  ('DR Congo', ('DR Congo', 100)),
#  ('Faeroe Islands', ('Faeroe Islands', 100)),
#  ('Falkland Islands', ('Falkland Islands', 100)),
#  ('French Guiana', ('French Guiana', 100)),
#  ('Gambia', ('Gambia', 100)),
#  ('Guadeloupe', ('Guadeloupe', 100)),
#  ('Holy See', ('Holy See', 100)),
#  ('Isle of Man', ('Isle of Man', 100)),
#  ('Liechtenstein', ('Liechtenstein', 100)),
#  ('Macao', ('Macao', 100)),
#  ('Martinique', ('Martinique', 100)),
#  ('Mayotte', ('Mayotte', 100)),
#  ('Micronesia', ('Micronesia', 100)),
#  ('Monaco', ('Monaco', 100)),
#  ('Myanmar', ('Myanmar', 100)),
#  ('North Korea', ('North Korea', 100)),
# ...

# %%
#95
[(f,fz.extractOne(f ,onlyco2)) for f in sorted(onlyarea)
 if fz.extractOne(f ,onlyco2)[1]>=87]
# Out:
# [('Andorra', ('Andorra', 100)),
#  ('Anguilla', ('Anguilla', 100)),
#  ('Bahamas', ('Bahamas', 100)),
#  ('Caribbean Netherlands', ('Caribbean Netherlands', 100)),
#  ('Congo', ('Congo', 100)),
#  ('Curaçao', ('Curaçao', 100)),
#  ('Czech Republic (Czechia)', ('Czech Republic (Czechia)', 100)),
#  ("Côte d'Ivoire", ("Côte d'Ivoire", 100)),
#  ('DR Congo', ('DR Congo', 100)),
#  ('Faeroe Islands', ('Faeroe Islands', 100)),
#  ('Falkland Islands', ('Falkland Islands', 100)),
#  ('French Guiana', ('French Guiana', 100)),
#  ('Gambia', ('Gambia', 100)),
#  ('Guadeloupe', ('Guadeloupe', 100)),
#  ('Holy See', ('Holy See', 100)),
#  ('Isle of Man', ('Isle of Man', 100)),
#  ('Liechtenstein', ('Liechtenstein', 100)),
#  ('Macao', ('Macao', 100)),
#  ('Martinique', ('Martinique', 100)),
#  ('Mayotte', ('Mayotte', 100)),
#  ('Micronesia', ('Micronesia', 100)),
#  ('Monaco', ('Monaco', 100)),
#  ('Myanmar', ('Myanmar', 100)),
#  ('North Korea', ('North Korea', 100)),
# ...

# %%
cambioco2yarea= {f:fz.extractOne(f, onlyco2)[0] 
                 for f in sorted(onlyarea)
                 if fz.extractOne(f, onlyco2)[1] >=87}
cambioco2yarea
# Out:
# {'Andorra': 'Andorra',
#  'Anguilla': 'Anguilla',
#  'Bahamas': 'Bahamas',
#  'Caribbean Netherlands': 'Caribbean Netherlands',
#  'Congo': 'Congo',
#  'Curaçao': 'Curaçao',
#  'Czech Republic (Czechia)': 'Czech Republic (Czechia)',
#  "Côte d'Ivoire": "Côte d'Ivoire",
#  'DR Congo': 'DR Congo',
#  'Faeroe Islands': 'Faeroe Islands',
#  'Falkland Islands': 'Falkland Islands',
#  'French Guiana': 'French Guiana',
#  'Gambia': 'Gambia',
#  'Guadeloupe': 'Guadeloupe',
#  'Holy See': 'Holy See',
#  'Isle of Man': 'Isle of Man',
#  'Liechtenstein': 'Liechtenstein',
#  'Macao': 'Macao',
#  'Martinique': 'Martinique',
#  'Mayotte': 'Mayotte',
#  'Micronesia': 'Micronesia',
#  'Monaco': 'Monaco',
#  'Myanmar': 'Myanmar',
#  'North Korea': 'North Korea',
#  'Palau': 'Palau',
#  'Réunion': 'Réunion',
#  'Saint Barthelemy': 'Saint Barthelemy',
#  'Saint Helena': 'Saint Helena',
#  'Saint Kitts & Nevis': 'Saint Kitts & Nevis',
#  'Saint Martin': 'Saint Martin',
# ...

# %%
co2["Country"].replace(to_replace=cambioco2yarea, inplace=True)
co2
# Out:
#      Rank                                        Country  \
# 0       1                                          China
# 1       2                                  United States
# 2       3                                          India
# 3       4                                         Russia
# 4       5                                          Japan
# ..    ...                                            ...
# 213   214                                     Antarctica
# 214   215  Saint Helena, Ascension, and Tristan da Cunha
# 215   216                                           Niue
# 216   217                       Northern Mariana Islands
# 217   218                                         Tuvalu
#
#      metric tonnes of CO2 Date of Information
# 0             10773248000           2019 est.
# 1              5144361000           2019 est.
# 2              2314738000           2019 est.
# 3              1848070000           2019 est.
# ...

# %%
merge0 =co2.merge(area,left_on='Country',right_on='Country')
merge0
# Out:
#      Rank                   Country  metric tonnes of CO2 Date of Information  \
# 0       1                     China           10773248000           2019 est.
# 1       2             United States            5144361000           2019 est.
# 2       3                     India            2314738000           2019 est.
# 3       4                    Russia            1848070000           2019 est.
# 4       5                     Japan            1103234000           2019 est.
# ..    ...                       ...                   ...                 ...
# 186   211                     Nauru                 66000           2019 est.
# 187   213                Montserrat                 33000           2019 est.
# 188   216                      Niue                  8000           2019 est.
# 189   217  Northern Mariana Islands                     0           2019 est.
# 190   218                    Tuvalu                     0           2019 est.
#
# ...

# %%
Onlymerge0=set(merge0.Country)-set(precipitation.Country)
Onlyprecipitation=set(precipitation.Country)-set(merge0.Country)
[(f,fz.extractOne(f, Onlymerge0)) for f in sorted(Onlyprecipitation)]
# Out:
# [('Congo', ('Tonga', 60)),
#  ('Czech Republic', ('French Polynesia', 47)),
#  ("Côte d'Ivoire", ('New Caledonia', 46)),
#  ("Dem. People's Rep. Korea", ('Laos', 45)),
#  ('Dem. Rep. Congo', ('Tonga', 54)),
#  ('Korea', ('Kiribati', 46)),
#  ('Kyrgyz Republic', ('Kyrgyzstan', 54)),
#  ('Lao PDR', ('Laos', 68)),
#  ('Myanmar', ('Northern Mariana Islands', 51)),
#  ('Slovak Republic', ('Slovakia', 74)),
#  ('St. Kitts and Nevis', ('Marshall Islands', 46)),
#  ('St. Lucia', ('Saint Lucia', 80)),
#  ('St. Vincent and the Grenadines', ('Greenland', 57)),
#  ('Syrian Arab Republic', ('Syria', 90)),
#  ('São Tomé and Principe', ('Tonga', 54)),
#  ('The Bahamas', ('Northern Mariana Islands', 50)),
#  ('The Gambia', ('Guam', 68)),
#  ('Turkey', ('Niue', 45))]

# %%
[(f,fz.extractOne(f ,Onlymerge0)) for f in sorted(Onlyprecipitation)
 if fz.extractOne(f ,Onlymerge0)[1]>=87]
# Out:
# [('Syrian Arab Republic', ('Syria', 90))]

# %%
cambiomarge0yprecipitation = {f:fz.extractOne(f, Onlymerge0)[0] 
                 for f in sorted(Onlyprecipitation)
                 if fz.extractOne(f, Onlymerge0)[1] >=87}
cambiomarge0yprecipitation
# Out:
# {'Syrian Arab Republic': 'Syria'}

# %%
merge0["Country"].replace(to_replace=cambiomarge0yprecipitation, inplace=True)
merge0
# Out:
#      Rank                   Country  metric tonnes of CO2 Date of Information  \
# 0       1                     China           10773248000           2019 est.
# 1       2             United States            5144361000           2019 est.
# 2       3                     India            2314738000           2019 est.
# 3       4                    Russia            1848070000           2019 est.
# 4       5                     Japan            1103234000           2019 est.
# ..    ...                       ...                   ...                 ...
# 186   211                     Nauru                 66000           2019 est.
# 187   213                Montserrat                 33000           2019 est.
# 188   216                      Niue                  8000           2019 est.
# 189   217  Northern Mariana Islands                     0           2019 est.
# 190   218                    Tuvalu                     0           2019 est.
#
# ...

# %%
merge1 = merge0.merge(precipitation,left_on='Country',right_on='Country')
merge1
# Out:
#      Rank_x                   Country  metric tonnes of CO2  \
# 0         1                     China           10773248000
# 1         2             United States            5144361000
# 2         3                     India            2314738000
# 3         4                    Russia            1848070000
# 4         5                     Japan            1103234000
# ..      ...                       ...                   ...
# 156     195                   Comoros                326000
# 157     196                   Grenada                316000
# 158     198  Central African Republic                285000
# 159     201                   Vanuatu                225000
# 160     203                  Dominica                182000
#
#     Date of Information    #  Population  (2023) Yearly  Change  Net  Change  \
# 0             2019 est.    2          1425671352        -0.02 %      -215985
# 1             2019 est.    3           339996563         0.50 %      1706706
# ...

# %%
#104
import os
country_isosLink='https://github.com/IntroCDE2023/EVALUACION-01/raw/main/country_isos.xlsx'
country_isos=pd.read_excel(os.path.join('country_isos.xlsx'))
country_isos
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# ...

# %%
merge1['Country'] = merge1['Country'].str.upper()
merge1
# Out:
#      Rank_x                   Country  metric tonnes of CO2  \
# 0         1                     CHINA           10773248000
# 1         2             UNITED STATES            5144361000
# 2         3                     INDIA            2314738000
# 3         4                    RUSSIA            1848070000
# 4         5                     JAPAN            1103234000
# ..      ...                       ...                   ...
# 156     195                   COMOROS                326000
# 157     196                   GRENADA                316000
# 158     198  CENTRAL AFRICAN REPUBLIC                285000
# 159     201                   VANUATU                225000
# 160     203                  DOMINICA                182000
#
#     Date of Information    #  Population  (2023) Yearly  Change  Net  Change  \
# 0             2019 est.    2          1425671352        -0.02 %      -215985
# 1             2019 est.    3           339996563         0.50 %      1706706
# ...

# %%
Onlymarge1=set(merge1.Country)-set(country_isos.Country)
Onlycountry_isos=set(country_isos.Country)-set(merge1.Country)
[(f,fz.extractOne(f, onlyco2)) for f in sorted(onlyarea)]
# Out:
# [('Andorra', ('Andorra', 100)),
#  ('Anguilla', ('Anguilla', 100)),
#  ('Bahamas', ('Bahamas', 100)),
#  ('Caribbean Netherlands', ('Caribbean Netherlands', 100)),
#  ('Congo', ('Congo', 100)),
#  ('Curaçao', ('Curaçao', 100)),
#  ('Czech Republic (Czechia)', ('Czech Republic (Czechia)', 100)),
#  ("Côte d'Ivoire", ("Côte d'Ivoire", 100)),
#  ('DR Congo', ('DR Congo', 100)),
#  ('Faeroe Islands', ('Faeroe Islands', 100)),
#  ('Falkland Islands', ('Falkland Islands', 100)),
#  ('French Guiana', ('French Guiana', 100)),
#  ('Gambia', ('Gambia', 100)),
#  ('Guadeloupe', ('Guadeloupe', 100)),
#  ('Holy See', ('Holy See', 100)),
#  ('Isle of Man', ('Isle of Man', 100)),
#  ('Liechtenstein', ('Liechtenstein', 100)),
#  ('Macao', ('Macao', 100)),
#  ('Martinique', ('Martinique', 100)),
#  ('Mayotte', ('Mayotte', 100)),
#  ('Micronesia', ('Micronesia', 100)),
#  ('Monaco', ('Monaco', 100)),
#  ('Myanmar', ('Myanmar', 100)),
#  ('North Korea', ('North Korea', 100)),
# ...

# %%
[(f,fz.extractOne(f ,Onlymarge1)) for f in sorted(Onlycountry_isos)
 if fz.extractOne(f ,Onlymarge1)[1]>=87]
# Out:
# [('BOLIVIA (PLURINATIONAL STATE OF)', ('BOLIVIA', 90)),
#  ('BRUNEI DARUSSALAM', ('BRUNEI', 90)),
#  ('CENTRAL AFRICAN REPUBLIC (THE)', ('CENTRAL AFRICAN REPUBLIC', 95)),
#  ('COMOROS (THE)', ('COMOROS', 90)),
#  ('DOMINICAN REPUBLIC (THE)', ('DOMINICAN REPUBLIC', 95)),
#  ('IRAN (ISLAMIC REPUBLIC OF)', ('IRAN', 90)),
#  ('MOLDOVA (THE REPUBLIC OF)', ('MOLDOVA', 90)),
#  ('NETHERLANDS (THE)', ('NETHERLANDS', 95)),
#  ('NIGER (THE)', ('NIGER', 90)),
#  ('PHILIPPINES (THE)', ('PHILIPPINES', 95)),
#  ('RUSSIAN FEDERATION (THE)', ('RUSSIA', 90)),
#  ('SOUTH SUDAN', ('SUDAN', 90)),
#  ('SUDAN (THE)', ('SUDAN', 90)),
#  ('TANZANIA, THE UNITED REPUBLIC OF', ('TANZANIA', 90)),
#  ('UNITED ARAB EMIRATES (THE)', ('UNITED ARAB EMIRATES', 95)),
#  ('UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
#   ('UNITED KINGDOM', 90)),
#  ('UNITED STATES MINOR OUTLYING ISLANDS (THE)', ('UNITED STATES', 90)),
#  ('VIET NAM', ('VIETNAM', 93))]

# %%
cambiocountryymerge1 = {f:fz.extractOne(f, Onlymarge1)[0] 
                 for f in sorted(Onlycountry_isos)
                 if fz.extractOne(f, Onlymarge1)[1] >=87}
cambiocountryymerge1
# Out:
# {'BOLIVIA (PLURINATIONAL STATE OF)': 'BOLIVIA',
#  'BRUNEI DARUSSALAM': 'BRUNEI',
#  'CENTRAL AFRICAN REPUBLIC (THE)': 'CENTRAL AFRICAN REPUBLIC',
#  'COMOROS (THE)': 'COMOROS',
#  'DOMINICAN REPUBLIC (THE)': 'DOMINICAN REPUBLIC',
#  'IRAN (ISLAMIC REPUBLIC OF)': 'IRAN',
#  'MOLDOVA (THE REPUBLIC OF)': 'MOLDOVA',
#  'NETHERLANDS (THE)': 'NETHERLANDS',
#  'NIGER (THE)': 'NIGER',
#  'PHILIPPINES (THE)': 'PHILIPPINES',
#  'RUSSIAN FEDERATION (THE)': 'RUSSIA',
#  'SOUTH SUDAN': 'SUDAN',
#  'SUDAN (THE)': 'SUDAN',
#  'TANZANIA, THE UNITED REPUBLIC OF': 'TANZANIA',
#  'UNITED ARAB EMIRATES (THE)': 'UNITED ARAB EMIRATES',
#  'UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)': 'UNITED KINGDOM',
#  'UNITED STATES MINOR OUTLYING ISLANDS (THE)': 'UNITED STATES',
#  'VIET NAM': 'VIETNAM'}

# %%
merge1["Country"].replace(to_replace=cambiocountryymerge1 ,inplace=True)
merge1
# Out:
#      Rank_x                   Country  metric tonnes of CO2  \
# 0         1                     CHINA           10773248000
# 1         2             UNITED STATES            5144361000
# 2         3                     INDIA            2314738000
# 3         4                    RUSSIA            1848070000
# 4         5                     JAPAN            1103234000
# ..      ...                       ...                   ...
# 156     195                   COMOROS                326000
# 157     196                   GRENADA                316000
# 158     198  CENTRAL AFRICAN REPUBLIC                285000
# 159     201                   VANUATU                225000
# 160     203                  DOMINICA                182000
#
#     Date of Information    #  Population  (2023) Yearly  Change  Net  Change  \
# 0             2019 est.    2          1425671352        -0.02 %      -215985
# 1             2019 est.    3           339996563         0.50 %      1706706
# ...

# %%
merge_result = country_isos.merge(merge1,left_on='Country',right_on='Country')
merge_result
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 131              URUGUAY             The Oriental Republic of Uruguay
# 132           UZBEKISTAN                   The Republic of Uzbekistan
# 133                YEMEN                        The Republic of Yemen
# 134               ZAMBIA                       The Republic of Zambia
# 135             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3  Rank_x  metric tonnes of CO2 Date of Information  \
# ...

# %%
merge_result.columns
# Out:
# Index(['Country', 'Officialstatename', 'InternetccTLD', 'iso2', 'iso3',
#        'Rank_x', 'metric tonnes of CO2', 'Date of Information', '#',
#        'Population  (2023)', 'Yearly  Change', 'Net  Change',
#        'Density  (P/Km²)', 'Land Area  (Km²)', 'Migrants  (net)',
#        'Fert.  Rate', 'Med.  Age', 'Urban  Pop %', 'World  Share', 'Rank_y',
#        'Value', 'Year'],
#       dtype='object')

# %%
merge_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               136 non-null    object
#  1   Officialstatename     136 non-null    object
#  2   InternetccTLD         136 non-null    object
#  3   iso2                  135 non-null    object
#  4   iso3                  136 non-null    object
#  5   Rank_x                136 non-null    int64
#  6   metric tonnes of CO2  136 non-null    int64
#  7   Date of Information   136 non-null    object
#  8   #                     136 non-null    int64
#  9   Population  (2023)    136 non-null    int64
#  10  Yearly  Change        136 non-null    object
#  11  Net  Change           136 non-null    int64
#  12  Density  (P/Km²)      136 non-null    int64
#  13  Land Area  (Km²)      136 non-null    int64
#  14  Migrants  (net)       136 non-null    int64
# ...

# %%
merge_result1 = merge_result.applymap(lambda x: x.strip() if isinstance(x, str) else x)
merge_result1
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 131              URUGUAY             The Oriental Republic of Uruguay
# 132           UZBEKISTAN                   The Republic of Uzbekistan
# 133                YEMEN                        The Republic of Yemen
# 134               ZAMBIA                       The Republic of Zambia
# 135             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3  Rank_x  metric tonnes of CO2 Date of Information  \
# ...

# %%
merge_result1['Officialstatename'] = merge_result1['Officialstatename'].str.replace(' ', '')
merge_result1
# Out:
#                  Country                       Officialstatename  \
# 0            AFGHANISTAN         TheIslamicRepublicofAfghanistan
# 1                ALBANIA                    TheRepublicofAlbania
# 2                ALGERIA  ThePeople'sDemocraticRepublicofAlgeria
# 3                 ANGOLA                     TheRepublicofAngola
# 4    ANTIGUA AND BARBUDA                       AntiguaandBarbuda
# ..                   ...                                     ...
# 131              URUGUAY            TheOrientalRepublicofUruguay
# 132           UZBEKISTAN                 TheRepublicofUzbekistan
# 133                YEMEN                      TheRepublicofYemen
# 134               ZAMBIA                     TheRepublicofZambia
# 135             ZIMBABWE                   TheRepublicofZimbabwe
#
#     InternetccTLD iso2 iso3  Rank_x  metric tonnes of CO2 Date of Information  \
# 0             .af   AF  AFG     117               7893000           2019 est.
# ...

# %%
merge_result1.columns=merge_result1.columns.str.replace(" ", "_")
merge_result1
# Out:
#                  Country                       Officialstatename  \
# 0            AFGHANISTAN         TheIslamicRepublicofAfghanistan
# 1                ALBANIA                    TheRepublicofAlbania
# 2                ALGERIA  ThePeople'sDemocraticRepublicofAlgeria
# 3                 ANGOLA                     TheRepublicofAngola
# 4    ANTIGUA AND BARBUDA                       AntiguaandBarbuda
# ..                   ...                                     ...
# 131              URUGUAY            TheOrientalRepublicofUruguay
# 132           UZBEKISTAN                 TheRepublicofUzbekistan
# 133                YEMEN                      TheRepublicofYemen
# 134               ZAMBIA                     TheRepublicofZambia
# 135             ZIMBABWE                   TheRepublicofZimbabwe
#
#     InternetccTLD iso2 iso3  Rank_x  metric_tonnes_of_CO2 Date_of_Information  \
# 0             .af   AF  AFG     117               7893000           2019 est.
# ...

# %%
merge_result1.columns
# Out:
# Index(['Country', 'Officialstatename', 'InternetccTLD', 'iso2', 'iso3',
#        'Rank_x', 'metric_tonnes_of_CO2', 'Date_of_Information', '#',
#        'Population__(2023)', 'Yearly__Change', 'Net__Change',
#        'Density__(P/Km²)', 'Land_Area__(Km²)', 'Migrants__(net)',
#        'Fert.__Rate', 'Med.__Age', 'Urban__Pop_%', 'World__Share', 'Rank_y',
#        'Value', 'Year'],
#       dtype='object')

# %%
merge_result1.columns.to_list()
# Out:
# ['Country',
#  'Officialstatename',
#  'InternetccTLD',
#  'iso2',
#  'iso3',
#  'Rank_x',
#  'metric_tonnes_of_CO2',
#  'Date_of_Information',
#  '#',
#  'Population__(2023)',
#  'Yearly__Change',
#  'Net__Change',
#  'Density__(P/Km²)',
#  'Land_Area__(Km²)',
#  'Migrants__(net)',
#  'Fert.__Rate',
#  'Med.__Age',
#  'Urban__Pop_%',
#  'World__Share',
#  'Rank_y',
#  'Value',
#  'Year']

# %%
merge_result1.rename(columns={'metric_tonnes_of_CO2':"co2 (Ton)"},inplace=True)
merge_result1
# Out:
#                  Country                       Officialstatename  \
# 0            AFGHANISTAN         TheIslamicRepublicofAfghanistan
# 1                ALBANIA                    TheRepublicofAlbania
# 2                ALGERIA  ThePeople'sDemocraticRepublicofAlgeria
# 3                 ANGOLA                     TheRepublicofAngola
# 4    ANTIGUA AND BARBUDA                       AntiguaandBarbuda
# ..                   ...                                     ...
# 131              URUGUAY            TheOrientalRepublicofUruguay
# 132           UZBEKISTAN                 TheRepublicofUzbekistan
# 133                YEMEN                      TheRepublicofYemen
# 134               ZAMBIA                     TheRepublicofZambia
# 135             ZIMBABWE                   TheRepublicofZimbabwe
#
#     InternetccTLD iso2 iso3  Rank_x  co2 (Ton) Date_of_Information    #  \
# 0             .af   AF  AFG     117    7893000           2019 est.   36
# ...

# %%
merge_result1.rename(columns={'Land_Area__(Km²)':"area (Km²)"},inplace=True)
merge_result1
# Out:
#                  Country                       Officialstatename  \
# 0            AFGHANISTAN         TheIslamicRepublicofAfghanistan
# 1                ALBANIA                    TheRepublicofAlbania
# 2                ALGERIA  ThePeople'sDemocraticRepublicofAlgeria
# 3                 ANGOLA                     TheRepublicofAngola
# 4    ANTIGUA AND BARBUDA                       AntiguaandBarbuda
# ..                   ...                                     ...
# 131              URUGUAY            TheOrientalRepublicofUruguay
# 132           UZBEKISTAN                 TheRepublicofUzbekistan
# 133                YEMEN                      TheRepublicofYemen
# 134               ZAMBIA                     TheRepublicofZambia
# 135             ZIMBABWE                   TheRepublicofZimbabwe
#
#     InternetccTLD iso2 iso3  Rank_x  co2 (Ton) Date_of_Information    #  \
# 0             .af   AF  AFG     117    7893000           2019 est.   36
# ...

# %%
merge_result1.rename(columns={'Value':"Precipitation (mm)"},inplace=True)
merge_result1
# Out:
#                  Country                       Officialstatename  \
# 0            AFGHANISTAN         TheIslamicRepublicofAfghanistan
# 1                ALBANIA                    TheRepublicofAlbania
# 2                ALGERIA  ThePeople'sDemocraticRepublicofAlgeria
# 3                 ANGOLA                     TheRepublicofAngola
# 4    ANTIGUA AND BARBUDA                       AntiguaandBarbuda
# ..                   ...                                     ...
# 131              URUGUAY            TheOrientalRepublicofUruguay
# 132           UZBEKISTAN                 TheRepublicofUzbekistan
# 133                YEMEN                      TheRepublicofYemen
# 134               ZAMBIA                     TheRepublicofZambia
# 135             ZIMBABWE                   TheRepublicofZimbabwe
#
#     InternetccTLD iso2 iso3  Rank_x  co2 (Ton) Date_of_Information    #  \
# 0             .af   AF  AFG     117    7893000           2019 est.   36
# ...

# %%
merge_result1.columns.to_list()
# Out:
# ['Country',
#  'Officialstatename',
#  'InternetccTLD',
#  'iso2',
#  'iso3',
#  'Rank_x',
#  'co2 (Ton)',
#  'Date_of_Information',
#  '#',
#  'Population__(2023)',
#  'Yearly__Change',
#  'Net__Change',
#  'Density__(P/Km²)',
#  'area (Km²)',
#  'Migrants__(net)',
#  'Fert.__Rate',
#  'Med.__Age',
#  'Urban__Pop_%',
#  'World__Share',
#  'Rank_y',
#  'Precipitation (mm)',
#  'Year']

# %%
columnas_a_mantener = ['Country','Officialstatename','InternetccTLD','iso2','iso3','co2 (Ton)','area (Km²)','Precipitation (mm)']
merge_result1=merge_result1[columnas_a_mantener]

# %%
merge_result1
# Out:
#                  Country                       Officialstatename  \
# 0            AFGHANISTAN         TheIslamicRepublicofAfghanistan
# 1                ALBANIA                    TheRepublicofAlbania
# 2                ALGERIA  ThePeople'sDemocraticRepublicofAlgeria
# 3                 ANGOLA                     TheRepublicofAngola
# 4    ANTIGUA AND BARBUDA                       AntiguaandBarbuda
# ..                   ...                                     ...
# 131              URUGUAY            TheOrientalRepublicofUruguay
# 132           UZBEKISTAN                 TheRepublicofUzbekistan
# 133                YEMEN                      TheRepublicofYemen
# 134               ZAMBIA                     TheRepublicofZambia
# 135             ZIMBABWE                   TheRepublicofZimbabwe
#
#     InternetccTLD iso2 iso3  co2 (Ton)  area (Km²)  Precipitation (mm)
# 0             .af   AF  AFG    7893000      652860               327.0
# ...

# %%
merge_result1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             136 non-null    object
#  1   Officialstatename   136 non-null    object
#  2   InternetccTLD       136 non-null    object
#  3   iso2                135 non-null    object
#  4   iso3                136 non-null    object
#  5   co2 (Ton)           136 non-null    int64
#  6   area (Km²)          136 non-null    int64
#  7   Precipitation (mm)  136 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 8.6+ KB
